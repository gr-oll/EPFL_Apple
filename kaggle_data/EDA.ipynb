# %%
import pandas as pd
import numpy as np
import requests

# %%
#import csv filee interactions_train.csv
interactions = pd.read_csv('interactions_train.csv')
items = pd.read_csv('items.csv')

display(interactions.head())
display(items.head())

#limited to 100 rows
limited_items = items.head(100)
# Out:
#       u      i             t
# 0  4456   8581  1.687541e+09
# 1   142   1964  1.679585e+09
# 2   362   3705  1.706872e+09
# 3  1809  11317  1.673533e+09
# 4  4384   1323  1.681402e+09
#                                                Title  \
# 0  Classification décimale universelle : édition ...
# 1  Les interactions dans l'enseignement des langu...
# 2  Histoire de vie et recherche biographique : pe...
# 3  Ce livre devrait me permettre de résoudre le c...
# 4                    Les années glorieuses : roman /
#
#                      Author  \
# 0                       NaN
# 1  Cicurel, Francine, 1947-
# 2                       NaN
# 3     Mazas, Sylvain, 1980-
# 4   Lemaitre, Pierre, 1951-
#
#                                           ISBN Valid     Publisher  \
# 0                          9782871303336; 2871303339   Ed du CEFAL
# 1                          9782278058327; 2278058320        Didier
# 2                          2343190194; 9782343190198   L'Harmattan
# 3  9782365350020; 236535002X; 9782365350488; 2365...       Vraoum!
# 4  9782702180815; 2702180817; 9782702183618; 2702...  Calmann-Lévy
#
#                                             Subjects  i
# 0  Classification décimale universelle; Indexatio...  0
# 1  didactique--langue étrangère - enseignement; d...  1
# 2  Histoires de vie en sociologie; Sciences socia...  2
# 3  Moyen-Orient; Bandes dessinées autobiographiqu...  3
# 4  France--1945-1975; Roman historique; Roman fra...  4

# %% [markdown]
# ## Functions

# %%
def get_book_metadata(isbn):
    api_url = f"https://www.googleapis.com/books/v1/volumes?q=isbn:{isbn}"

    try:
        response = requests.get(api_url)
        response.raise_for_status()  # Exception for HTTP errors
        data = response.json()

        if 'items' in data:
            metadata = []
            for item in data['items']:
                volume_info = item['volumeInfo']
                book_data = {
                    'title': volume_info.get('title'),
                    'authors': volume_info.get('authors'),
                    'language': volume_info.get('language'),
                    'publisher': volume_info.get('publisher'),
                    'published_date': volume_info.get('publishedDate'),
                    'subjects': volume_info.get('categories')  
                }
                metadata.append(book_data)
            return metadata
        else:
            return {"error": "No books found matching that ISBN."}
    except requests.exceptions.RequestException as e:
        return {"error": f"An error occurred: {e}"}

# Example usage:
isbn = "9782702180815"
book_metadata = get_book_metadata(isbn)
book_metadata
# Out:
# [{'title': 'Le grand monde',
#   'authors': ['Pierre Lemaitre'],
#   'language': 'fr',
#   'publisher': None,
#   'published_date': '2022',
#   'subjects': ['French literature']}]

# %%
#identify missing values for items
missing_values = items.isnull().sum()
missing_values
# Out:
# Title            0
# Author        2653
# ISBN Valid     723
# Publisher       25
# Subjects      2223
# i                0
# dtype: int64

# %%
#count the number of elements in each column
count_elements = items.count()
count_elements
# Out:
# Title         15291
# Author        12638
# ISBN Valid    14568
# Publisher     15266
# Subjects      13068
# i             15291
# dtype: int64

# %%
limited_items
# Out:
#                                                 Title  \
# 0   Classification décimale universelle : édition ...
# 1   Les interactions dans l'enseignement des langu...
# 2   Histoire de vie et recherche biographique : pe...
# 3   Ce livre devrait me permettre de résoudre le c...
# 4                     Les années glorieuses : roman /
# ..                                                ...
# 95                                    Akane banashi /
# 96                                 Des maux à dire /
# 97                   Il y a longtemps que je t'aime /
# 98                   Regarde les lumières mon amour /
# 99                                             Peau /
#
#                       Author  \
# 0                        NaN
# 1   Cicurel, Francine, 1947-
# 2                        NaN
# 3      Mazas, Sylvain, 1980-
# 4    Lemaitre, Pierre, 1951-
# ..                       ...
# 95   Suenaga, Yuki 19..-....
# 96   Lema, Beatriz 1985-....
# 97            Spénale, Marie
# 98             Ernaux, Annie
# 99   Versyp, Mieke 1965-....
#
#                                            ISBN Valid     Publisher  \
# 0                           9782871303336; 2871303339   Ed du CEFAL
# 1                           9782278058327; 2278058320        Didier
# 2                           2343190194; 9782343190198   L'Harmattan
# 3   9782365350020; 236535002X; 9782365350488; 2365...       Vraoum!
# 4   9782702180815; 2702180817; 9782702183618; 2702...  Calmann-Lévy
# ..                                                ...           ...
# 95  9791032715413; 9791032715420; 9791032715437; 9...        Ki-oon
# 96                                      9791040802396     Sarbacane
# 97                          2203276509; 9782203276505     Casterman
# 98                          9782370210371; 2370210370         Seuil
# 99                          9782369903093; 2369903090   Çà et là
#
#                                              Subjects   i
# 0   Classification décimale universelle; Indexatio...   0
# 1   didactique--langue étrangère - enseignement; d...   1
# 2   Histoires de vie en sociologie; Sciences socia...   2
# 3   Moyen-Orient; Bandes dessinées autobiographiqu...   3
# 4   France--1945-1975; Roman historique; Roman fra...   4
# ..                                                ...  ..
# 95                                    Mangas; Mangas.  95
# 96  Bandes dessinées; Mères et filles; Maladies me...  96
# 97                                   Bandes dessinées  97
# 98                                                NaN  98
# 99             Bandes dessinées.; Romans graphiques.  99
#
# [100 rows x 6 columns]

# %%
# Initialize a list to store metadata
limited_metadata_list = []

# Iterate over the limited_items DataFrame
for _, row in limited_items.iterrows():
    isbn = row['ISBN Valid']
    if pd.notnull(isbn):  # Ensure the ISBN is not NaN
        primary_isbn = isbn.split(';')[0]  # Use the first ISBN if multiple are listed
        metadata = get_book_metadata(primary_isbn)
        if isinstance(metadata, list):  # Ensure metadata is a list of dictionaries
            for entry in metadata:
                entry['i'] = row['i']  # Add the 'i' column value to the metadata
                entry['title'] = row['Title']  # Add the 'Title' column value to the metadata
                entry['isbn'] = row['ISBN Valid']  # Add the 'ISBN Valid' column value to the metadata
                limited_metadata_list.append(entry)

# Create a new DataFrame from the collected metadata
limited_metadata_df = pd.DataFrame(
    limited_metadata_list, 
    columns=['authors', 'publisher', 'subjects', 'language', 'published_date', 'i', 'title', 'isbn']
)

# Display the new DataFrame
limited_metadata_df.head()
# Out:
#                                        authors                     publisher  \
# 0                 [UDC Consortium (The Hague)]                          None
# 1                           [Francine Cicurel]               Editions Didier
# 2  [Aneta Slowik, Hervé Breton, Gaston Pineau]  Histoire de vie et formation
# 3                              [Sylvain Mazas]                      Vraoum !
# 4                            [Pierre Lemaitre]                          None
#
#                                 subjects language published_date  i  \
# 0                                   None       fr           2012  0
# 1    [Interaction analysis in education]       fr           2011  1
# 2  [Narrative inquiry (Research method)]       fr           2020  2
# 3                                   None       fr     2012-06-07  3
# 4                    [French literature]       fr           2022  4
#
#                                                title  \
# 0  Classification décimale universelle : édition ...
# 1  Les interactions dans l'enseignement des langu...
# 2  Histoire de vie et recherche biographique : pe...
# 3  Ce livre devrait me permettre de résoudre le c...
# 4                    Les années glorieuses : roman /
#
#                                                 isbn
# 0                          9782871303336; 2871303339
# 1                          9782278058327; 2278058320
# 2                          2343190194; 9782343190198
# 3  9782365350020; 236535002X; 9782365350488; 2365...
# 4  9782702180815; 2702180817; 9782702183618; 2702...
